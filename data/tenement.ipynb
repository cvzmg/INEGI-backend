# %%
import pandas as pd

# %%
df = pd.read_csv("./raw/tenement/conjunto_de_datos_iter_09CSV20.csv")
df.head()
# Out:
#    ENTIDAD           NOM_ENT  MUN                               NOM_MUN   LOC  \
# 0        9  Ciudad de México    0  Total de la entidad Ciudad de México     0
# 1        9  Ciudad de México    0  Total de la entidad Ciudad de México  9998
# 2        9  Ciudad de México    0  Total de la entidad Ciudad de México  9999
# 3        9  Ciudad de México    2                          Azcapotzalco     0
# 4        9  Ciudad de México    2                          Azcapotzalco     1
#
#                         NOM_LOC          LONGITUD          LATITUD  ALTITUD  \
# 0           Total de la Entidad               NaN              NaN      NaN
# 1   Localidades de una vivienda               NaN              NaN      NaN
# 2  Localidades de dos viviendas               NaN              NaN      NaN
# 3           Total del Municipio               NaN              NaN      NaN
# 4                  Azcapotzalco   99°11'03.698" W  19°29'02.770" N   2244.0
#
# ...

# %%
df = df[[ "NOM_MUN","NOM_LOC","POBTOT","POBFEM","POBMAS","P_18YMAS","P_18YMAS_F","P_18YMAS_M","P_60YMAS","P_60YMAS_F","P_60YMAS_M","P_18A24","P_18A24_F","P_18A24_M","P_25A29","P_25A29_F","P_25A29_M","PCON_DISC","P12YM_CASA","PCATOLICA","PRO_CRIEVA","POTRAS_REL","PSIN_RELIG","PROM_OCUP","VPH_PISODT","VPH_PISOTI","VPH_C_ELEC","VPH_S_ELEC","VPH_AEASP","VPH_AGUAFV","VPH_DRENAJ","VPH_NODREN","VPH_SNBIEN","VPH_REFRI","VPH_LAVAD","VPH_HMICRO","VPH_AUTOM","VPH_MOTO","VPH_BICI","VPH_RADIO","VPH_TV","VPH_PC","VPH_TELEF","VPH_CEL","VPH_INTER","VPH_STVP","VPH_SPMVPI","VPH_CVJ"]]
df
# Out:
#                                   NOM_MUN                       NOM_LOC  \
# 0    Total de la entidad Ciudad de México           Total de la Entidad
# 1    Total de la entidad Ciudad de México   Localidades de una vivienda
# 2    Total de la entidad Ciudad de México  Localidades de dos viviendas
# 3                            Azcapotzalco           Total del Municipio
# 4                            Azcapotzalco                  Azcapotzalco
# ..                                    ...                           ...
# 661                            Cuauhtémoc                    Cuauhtémoc
# 662                        Miguel Hidalgo           Total del Municipio
# 663                        Miguel Hidalgo                Miguel Hidalgo
# 664                   Venustiano Carranza           Total del Municipio
# 665                   Venustiano Carranza           Venustiano Carranza
#
#       POBTOT   POBFEM   POBMAS P_18YMAS P_18YMAS_F P_18YMAS_M P_60YMAS  \
# ...

# %%
df["NOM_MUN"].unique()
# Out:
# array(['Total de la entidad Ciudad de México', 'Azcapotzalco', 'Coyoacán',
#        'Cuajimalpa de Morelos', 'Gustavo A. Madero', 'Iztacalco',
#        'Iztapalapa', 'La Magdalena Contreras', 'Milpa Alta',
#        'Álvaro Obregón', 'Tláhuac', 'Tlalpan', 'Xochimilco',
#        'Benito Juárez', 'Cuauhtémoc', 'Miguel Hidalgo',
#        'Venustiano Carranza'], dtype=object)

# %%
df.query('NOM_LOC=="Total de la Entidad" or NOM_LOC=="Total del Municipio"').reset_index()
# Out:
#     index                               NOM_MUN              NOM_LOC   POBTOT  \
# 0       0  Total de la entidad Ciudad de México  Total de la Entidad  9209944
# 1       3                          Azcapotzalco  Total del Municipio   432205
# 2       5                              Coyoacán  Total del Municipio   614447
# 3       7                 Cuajimalpa de Morelos  Total del Municipio   217686
# 4      34                     Gustavo A. Madero  Total del Municipio  1173351
# 5      36                             Iztacalco  Total del Municipio   404695
# 6      38                            Iztapalapa  Total del Municipio  1835486
# 7      40                La Magdalena Contreras  Total del Municipio   247622
# 8      66                            Milpa Alta  Total del Municipio   152685
# 9     313                        Álvaro Obregón  Total del Municipio   759137
# 10    322                               Tláhuac  Total del Municipio   392313
# ...

# %%
df.to_csv("./output/tenement.csv", index=False)
