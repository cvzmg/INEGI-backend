# %%
import pandas as pd

# %%
work_data = pd.read_csv("./raw/laboral/work.csv")
work_data.rename(columns={'Unnamed: 0': 'ALCALDIA'}, inplace=True)
work_data
# Out:
#                                 ALCALDIA  \
# 0   Total de la entidad Ciudad de México
# 1                         Álvaro Obregón
# 2                           Azcapotzalco
# 3                          Benito Juárez
# 4                               Coyoacán
# 5                  Cuajimalpa de Morelos
# 6                             Cuauhtémoc
# 7                      Gustavo A. Madero
# 8                              Iztacalco
# 9                             Iztapalapa
# 10                La Magdalena Contreras
# 11                        Miguel Hidalgo
# 12                            Milpa Alta
# 13                               Tláhuac
# 14                               Tlalpan
# 15                   Venustiano Carranza
# 16                            Xochimilco
#
#     Funcionarios, profesionistas, técnicos y administrativos  \
# 0                                               43.91
# 1                                               42.30
# ...

# %%
work_data.to_csv("./output/work.csv", index=False)
